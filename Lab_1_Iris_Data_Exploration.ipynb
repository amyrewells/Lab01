# %% [markdown]
# # Lab 1: Iris Data Exploration and Visualization
#
# This lab is an open-ended exploration of the Iris dataset. There is no single required sequence of analyses and no need to complete every section.

# %% [markdown]
# ## Setup
#
# Run these cells to import the packages and load the dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv("data/iris.csv")
iris.head(10)
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm species
# 0              5.1             3.5              1.4             0.2  setosa
# 1              4.9             3.0              1.4             0.2  setosa
# 2              4.7             3.2              1.3             0.2  setosa
# 3              4.6             3.1              1.5             0.2  setosa
# 4              5.0             3.6              1.4             0.2  setosa
# 5              5.4             3.9              1.7             0.4  setosa
# 6              4.6             3.4              1.4             0.3  setosa
# 7              5.0             3.4              1.5             0.2  setosa
# 8              4.4             2.9              1.4             0.2  setosa
# 9              4.9             3.1              1.5             0.1  setosa

# %% [markdown]
# ## 1. Become familiar with the dataset
#
# Explore the structure and contents of the dataset.
#
# Consider:
#
# - **What does one row represent?**
# *Each row represents one iris*
#
# - **What does each column represent?**
# *Each column represents one feature or attribute of the iris*
#
# - **Which attributes are numeric and which are categorical?**
# *sepal_length_cm, sepeal_width_cm, petal_length_cm, and petal_width_cm are numerical*, *species is categorical*
#
# - **How large is the dataset?**
# *150 rows, 5 columns*
#
# - **Are any values missing?**
# *No*
#
# - **How many observations belong to each species?**
# *50*

# %%
# check the data types of the columns
print(iris.dtypes)
print("")

# check dimensions of the data frame
print(iris.shape)
print("")

# check for missing values
print(iris.isnull().sum())
print("")

# check for number of observations in each species
print(iris['species'].value_counts())
print()
# Out:
# sepal_length_cm    float64
# sepal_width_cm     float64
# petal_length_cm    float64
# petal_width_cm     float64
# species                str
# dtype: object
#
# (150, 5)
#
# sepal_length_cm    0
# sepal_width_cm     0
# petal_length_cm    0
# petal_width_cm     0
# species            0
# dtype: int64
#
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Develop questions about the data
#
# Write down questions that you could investigate.
#
# Possible starting points:
#
# - What are typical sepal and petal measurements for each species?
# - Are there any possible outliers?
# - Which attributes are related?
# - Which attributes appear most useful for distinguishing species?
# - What else would you like to learn from the data?
#
# **Your questions:**
#
# 1. Are petal length and sepal length corelated?
# 2. What trait can best predict species?
# 3. How does the distribution of data compare between species?

# %% [markdown]
# ## 3. Explore individual attributes
#
# Investigate one or more attributes on their own.
#
# Consider typical values, variability, the shape of the distribution, possible unusual observations, and whether the results change when the species are considered separately.

# %%
# get spepal and petal length mean
print("Mean sepal length:", iris['sepal_length_cm'].mean())
print("Mean petal length:", iris['petal_length_cm'].mean())

# get sepal and petal length median
print("Median sepal length:", iris['sepal_length_cm'].median())
print("Median petal length:", iris['petal_length_cm'].median())

# get spepal and petal length mode
print("Mode sepal length:", iris['sepal_length_cm'].mode()[0])
print("Mode petal length:", iris['petal_length_cm'].mode()[0])

# get spepal and petal length standard deviation
print("Standard deviation sepal length:", iris['sepal_length_cm'].std())
print("Standard deviation petal length:", iris['petal_length_cm'].std())

# plot histograms of sepal and petal length
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(iris['sepal_length_cm'], bins=20, color='blue', alpha=0.7)
plt.title('Histogram of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.subplot(1, 2, 2)
plt.hist(iris['petal_length_cm'], bins=20, color='orange', alpha=0.7)
plt.title('Histogram of Petal Length')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# Mean sepal length: 5.843333333333334
# Mean petal length: 3.7580000000000005
# Median sepal length: 5.8
# Median petal length: 4.35
# Mode sepal length: 5.0
# Mode petal length: 1.4
# Standard deviation sepal length: 0.828066127977863
# Standard deviation petal length: 1.7652982332594662

# %% [markdown]
# ## 4. Explore relationships between attributes
#
# Investigate relationships between two or more numeric attributes.
#
# Consider whether measurements increase together, whether the species form visible groups, whether relationships look different for different species, and whether some pairs of attributes are more useful than others.

# %%
# import scipy
# %pip install scipy
import scipy.stats as stats
print("")

# get correlation between sepal length and petal length
correlation = iris['sepal_length_cm'].corr(iris['petal_length_cm'])
print("Correlation between sepal length and petal length:", correlation)

# get p vallue for correlation
corr, p_value = stats.pearsonr(iris['sepal_length_cm'], iris['petal_length_cm'])
print("P-value for correlation:", p_value)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Correlation between sepal length and petal length: 0.8717537758865831
# P-value for correlation: 1.0386674194497458e-47

# %% [markdown]
# ## 5. Compare the species
#
# Explore how the measurements differ among the three Iris species.
#
# Consider:
#
# - Which measurements differ most visibly by species?
# - Which species appear easiest or hardest to distinguish?
# - Where is there substantial overlap?
# - Which summaries or visualizations help answer these questions?

# %%
# subset data by species
setosa = iris[iris['species'] == 'setosa']
versicolor = iris[iris['species'] == 'versicolor']
virginica = iris[iris['species'] == 'virginica']

# get correlation between sepal length and petal length for each species
setosa_corr = setosa['sepal_length_cm'].corr(setosa['petal_length_cm'])
versicolor_corr = versicolor['sepal_length_cm'].corr(versicolor['petal_length_cm'])
virginica_corr = virginica['sepal_length_cm'].corr(virginica['petal_length_cm'])
print("Correlation between sepal length and petal length for setosa:", setosa_corr)
print("Correlation between sepal length and petal length for versicolor:", versicolor_corr)
print("Correlation between sepal length and petal length for virginica:", virginica_corr)

# get p value for correlation between sepal length and petal length for each species
setosa_corr, setosa_p_value = stats.pearsonr(setosa['sepal_length_cm'], setosa['petal_length_cm'])
versicolor_corr, versicolor_p_value = stats.pearsonr(versicolor['sepal_length_cm'], versicolor['petal_length_cm'])
virginica_corr, virginica_p_value = stats.pearsonr(virginica['sepal_length_cm'], virginica['petal_length_cm'])
print("P-value for correlation between sepal length and petal length for setosa:", setosa_p_value)
print("P-value for correlation between sepal length and petal length for versicolor:", versicolor_p_value)
print("P-value for correlation between sepal length and petal length for virginica:", virginica_p_value)
# Out:
# Correlation between sepal length and petal length for setosa: 0.26717575886875716
# Correlation between sepal length and petal length for versicolor: 0.754048958592016
# Correlation between sepal length and petal length for virginica: 0.8642247329355764
# P-value for correlation between sepal length and petal length for setosa: 0.06069778380113451
# P-value for correlation between sepal length and petal length for versicolor: 2.586189505280907e-10
# P-value for correlation between sepal length and petal length for virginica: 6.297785758903822e-16

# %% [markdown]
# ## 6. Choose useful visualizations
#
# Try visualizations that match the questions you are asking.
#
# Possibilities include histograms, boxplots, scatterplots, bar charts, or a visualization of the correlation matrix.
#
# Think about what each visualization reveals and what it may hide.

# %%
# Plot petal length vs sepal length
plt.figure(figsize=(8, 6))
plt.scatter(iris['sepal_length_cm'], iris['petal_length_cm'], color='green', alpha=0.7)
plt.title('Petal Length vs Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')

# add a line of best fit
slope, intercept, r_value, p_value, std_err = stats.linregress(iris['sepal_length_cm'], iris['petal_length_cm'])
line = slope * iris['sepal_length_cm'] + intercept
plt.plot(iris['sepal_length_cm'], line, color='red', linewidth=2)

plt.show()

# %pip install seaborn
import seaborn as sns

# plot speal length vs petal length by species with lines of best fit
plt.figure(figsize=(8, 6))
sns.lmplot(x='sepal_length_cm', y='petal_length_cm', hue='species', data=iris, aspect=1.5)
plt.title('Sepal Length vs Petal Length with Lines of Best Fit')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.show()

# %% [markdown]
# ## 7. Identify informative attributes
#
# Which attribute, or combination of attributes, appears most useful for distinguishing the Iris species?
#
# Support your answer with evidence from your analysis.

# %%
# repeat with width instead of length
# plot speal width vs petal width by species with lines of best fit
plt.figure(figsize=(8, 6))
sns.lmplot(x='sepal_width_cm', y='petal_width_cm', hue='species', data=iris, aspect=1.5)
plt.title('Sepal Width vs Petal Width with Lines of Best Fit')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Petal Width (cm)')
plt.show()

# correlation and p value for sepal width and petal width by species
setosa_corr_width = setosa['sepal_width_cm'].corr(setosa['petal_width_cm'])
versicolor_corr_width = versicolor['sepal_width_cm'].corr(versicolor['petal_width_cm'])
virginica_corr_width = virginica['sepal_width_cm'].corr(virginica['petal_width_cm'])
setosa_corr_width, setosa_p_value_width = stats.pearsonr(setosa['sepal_width_cm'], setosa['petal_width_cm'])
versicolor_corr_width, versicolor_p_value_width = stats.pearsonr(versicolor['sepal_width_cm'], versicolor['petal_width_cm'])
virginica_corr_width, virginica_p_value_width = stats.pearsonr(virginica['sepal_width_cm'], virginica['petal_width_cm'])
print("Correlation between sepal width and petal width for setosa:", setosa_corr_width)
print("Correlation between sepal width and petal width for versicolor:", versicolor_corr_width)
print("Correlation between sepal width and petal width for virginica:", virginica_corr_width)
print("P-value for correlation between sepal width and petal width for setosa:", setosa_p_value_width)
print("P-value for correlation between sepal width and petal width for versicolor:", versicolor_p_value_width)
print("P-value for correlation between sepal width and petal width for virginica:", virginica_p_value_width)
# Out:
# Correlation between sepal width and petal width for setosa: 0.23275201136287926
# Correlation between sepal width and petal width for versicolor: 0.6639987200241115
# Correlation between sepal width and petal width for virginica: 0.5377280262661888
# P-value for correlation between sepal width and petal width for setosa: 0.10382114330524611
# P-value for correlation between sepal width and petal width for versicolor: 1.4666608142179456e-07
# P-value for correlation between sepal width and petal width for virginica: 5.6476104022877225e-05

# %% [markdown]
# **Your conclusion:**
#
# Petal length and sepal length are more correlated in all three species than petal width and sepal width

# %% [markdown]
# ## 8. Continue your own investigation
#
# Use the remaining space to investigate any new questions that arose while exploring the data.

# %%
# create correlation matrix for all numeric variables
numeric_cols = iris.select_dtypes(include=['float64']).columns
correlation_matrix = iris[numeric_cols].corr()

# plot correlation matrix as heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.show()

# plot correlation matrix by species
for species in iris['species'].unique():
    plt.figure(figsize=(8, 6))
    species_data = iris[iris['species'] == species]
    species_corr = species_data[numeric_cols].corr()
    sns.heatmap(species_corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
    plt.title(f'Correlation Matrix Heatmap - {species}')
    plt.show()

# plot pairplot of all numeric variables colored by species
sns.pairplot(iris, hue='species', diag_kind='hist')
plt.suptitle('Pairplot of Iris Dataset', y=1.02)
plt.show()

# rank the correlated pairs of variables by absolute value of correlation by species
for species in iris['species'].unique():
    species_data = iris[iris['species'] == species]
    species_corr = species_data[numeric_cols].corr().abs()
    species_corr_unstacked = species_corr.unstack()
    # keep only one of (a, b) or (b, a), and drop self-correlations
    species_corr_unstacked = species_corr_unstacked[species_corr_unstacked.index.get_level_values(0) < species_corr_unstacked.index.get_level_values(1)]
    sorted_pairs = species_corr_unstacked.sort_values(ascending=False)
    print(f"Top correlated pairs for {species}:")
    print(sorted_pairs.head(5))
    print()
# Out:
# Top correlated pairs for setosa:
# sepal_length_cm  sepal_width_cm     0.742547
# petal_length_cm  petal_width_cm     0.331630
# petal_width_cm   sepal_length_cm    0.278098
# petal_length_cm  sepal_length_cm    0.267176
# petal_width_cm   sepal_width_cm     0.232752
# dtype: float64
#
# Top correlated pairs for versicolor:
# petal_length_cm  petal_width_cm     0.786668
#                  sepal_length_cm    0.754049
# petal_width_cm   sepal_width_cm     0.663999
# petal_length_cm  sepal_width_cm     0.560522
# petal_width_cm   sepal_length_cm    0.546461
# dtype: float64
#
# Top correlated pairs for virginica:
# petal_length_cm  sepal_length_cm    0.864225
# petal_width_cm   sepal_width_cm     0.537728
# sepal_length_cm  sepal_width_cm     0.457228
# petal_length_cm  sepal_width_cm     0.401045
#                  petal_width_cm     0.322108
# dtype: float64
